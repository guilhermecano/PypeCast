# %% [markdown]
# # PypeCast - Simple example

# %% [markdown]
# ### Import the essential classes

# %%
import pandas as pd
from pypecast.models import MLP, Simple_LSTM
from pypecast.models.Het_LSTM import MDN_Het_LSTM
from pypecast.features import BuildFeaturesSupervised
from pypecast.descriptor import SeriesDescriptor
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('../data/example/monthly_milk.csv')

# %%
series = df.Production

# %% [markdown]
# ### Descriptor

# %%
sd = SeriesDescriptor()

# %%
sd.full_report(data=series)
# Out:
# -> Visualization of the series data:
# -> Description of the series data:
#        Production
# count  168.000000
# mean   754.708333
# std    102.204524
# min    553.000000
# 25%    677.750000
# 50%    761.000000
# 75%    824.500000
# max    969.000000
# -------------------- Histogram --------------------
# -> Autocorrelation and partial autocorrelation:
# -> Checking for outliers:

# %% [markdown]
# ### Build features for supervised learning

# %%
n_lag = 10 #Must define the lag window (ANN input size)
n_seq = 1 #Must also define the number of future timesteps to forecast

bf = BuildFeaturesSupervised(n_lag,n_seq, difference=True,scaler_type='std')

# %%
scaler, train, test = bf.transform_data(series)

# %% [markdown]
# ### Define a PypeCast Model

# %%
model = MDN_Het_LSTM(n_lag, n_seq)

# %% [markdown]
# #### Fit the model on training set

# %%
model.fit(train, n_batch = 10, n_epoch=100, early_stopping=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1, 10)        0
# __________________________________________________________________________________________________
# LSTM_1 (LSTM)                   (None, 5)            320         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            6           LSTM_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            6           LSTM_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            6           LSTM_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
# ==================================================================================================
# Total params: 338
# Trainable params: 338
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 94 samples, validate on 24 samples
# Epoch 1/100
#  - 1s - loss: 1.2877 - val_loss: 1.2889
# Epoch 2/100
#  - 0s - loss: 1.2654 - val_loss: 1.2672
# Epoch 3/100
#  - 0s - loss: 1.2440 - val_loss: 1.2462
# Epoch 4/100
#  - 0s - loss: 1.2231 - val_loss: 1.2257
# Epoch 5/100
#  - 0s - loss: 1.2025 - val_loss: 1.2056
# Epoch 6/100
#  - 0s - loss: 1.1822 - val_loss: 1.1857
# Epoch 7/100
#  - 0s - loss: 1.1619 - val_loss: 1.1657
# Epoch 8/100
#  - 0s - loss: 1.1415 - val_loss: 1.1455
# Epoch 9/100
#  - 0s - loss: 1.1208 - val_loss: 1.1248
# Epoch 10/100
#  - 0s - loss: 1.0998 - val_loss: 1.1036
# Epoch 11/100
#  - 0s - loss: 1.0782 - val_loss: 1.0817
# Epoch 12/100
#  - 0s - loss: 1.0560 - val_loss: 1.0588
# Epoch 13/100
#  - 0s - loss: 1.0330 - val_loss: 1.0349
# Epoch 14/100
#  - 0s - loss: 1.0091 - val_loss: 1.0099
# Epoch 15/100
#  - 0s - loss: 0.9841 - val_loss: 0.9839
# Epoch 16/100
#  - 0s - loss: 0.9582 - val_loss: 0.9566
# Epoch 17/100
#  - 0s - loss: 0.9312 - val_loss: 0.9282
# Epoch 18/100
#  - 0s - loss: 0.9033 - val_loss: 0.8985
# Epoch 19/100
#  - 0s - loss: 0.8750 - val_loss: 0.8680
# Epoch 20/100
#  - 0s - loss: 0.8462 - val_loss: 0.8368
# Epoch 21/100
#  - 0s - loss: 0.8170 - val_loss: 0.8052
# Epoch 22/100
#  - 0s - loss: 0.7875 - val_loss: 0.7737
# Epoch 23/100
#  - 0s - loss: 0.7578 - val_loss: 0.7425
# Epoch 24/100
#  - 0s - loss: 0.7277 - val_loss: 0.7117
# Epoch 25/100
#  - 0s - loss: 0.6974 - val_loss: 0.6816
# Epoch 26/100
#  - 0s - loss: 0.6670 - val_loss: 0.6525
# Epoch 27/100
#  - 0s - loss: 0.6366 - val_loss: 0.6250
# Epoch 28/100
#  - 0s - loss: 0.6066 - val_loss: 0.5992
# Epoch 29/100
#  - 0s - loss: 0.5773 - val_loss: 0.5753
# Epoch 30/100
#  - 0s - loss: 0.5486 - val_loss: 0.5534
# Epoch 31/100
#  - 0s - loss: 0.5209 - val_loss: 0.5337
# Epoch 32/100
#  - 0s - loss: 0.4943 - val_loss: 0.5161
# Epoch 33/100
#  - 0s - loss: 0.4688 - val_loss: 0.5008
# Epoch 34/100
#  - 0s - loss: 0.4445 - val_loss: 0.4879
# Epoch 35/100
#  - 0s - loss: 0.4213 - val_loss: 0.4771
# Epoch 36/100
#  - 0s - loss: 0.3991 - val_loss: 0.4685
# Epoch 37/100
#  - 0s - loss: 0.3781 - val_loss: 0.4607
# Epoch 38/100
#  - 0s - loss: 0.3580 - val_loss: 0.4504
# Epoch 39/100
#  - 0s - loss: 0.3387 - val_loss: 0.4406
# Epoch 40/100
#  - 0s - loss: 0.3200 - val_loss: 0.4318
# Epoch 41/100
#  - 0s - loss: 0.3019 - val_loss: 0.4240
# Epoch 42/100
#  - 0s - loss: 0.2843 - val_loss: 0.4171
# Epoch 43/100
#  - 0s - loss: 0.2675 - val_loss: 0.4111
# Epoch 44/100
#  - 0s - loss: 0.2512 - val_loss: 0.4056
# Epoch 45/100
#  - 0s - loss: 0.2354 - val_loss: 0.4007
# Epoch 46/100
#  - 0s - loss: 0.2199 - val_loss: 0.3971
# Epoch 47/100
#  - 0s - loss: 0.2049 - val_loss: 0.3947
# Epoch 48/100
#  - 0s - loss: 0.1903 - val_loss: 0.3933
# Epoch 49/100
#  - 0s - loss: 0.1762 - val_loss: 0.3923
# Epoch 50/100
#  - 0s - loss: 0.1624 - val_loss: 0.3923
# Epoch 51/100
#  - 0s - loss: 0.1491 - val_loss: 0.3930
# ------------------------------------------------------------
# Model trained

# %% [markdown]
# #### Make forecasts in the test set and evaluate them

# %%
forecasts = model.forecast_series(test=test, scaler=scaler, orig_series=series)

# %%
model.evaluate_forecast(keep_rate=0.3,save_report=True, filename='../reports/MDN1.xls')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e7378594aa5c> in <module>()
# ----> 1 model.evaluate_forecast(keep_rate=0.3,save_report=True, filename=model1)
#
# NameError: name 'model1' is not defined

# %%
model.plot_forecasts(forecasts=forecasts,series=series, test=test)
