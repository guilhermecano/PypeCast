# %%
import pandas as pd
from pypecast.models import MLP, Simple_LSTM
from pypecast.features import BuildFeaturesSupervised
from pypecast.descriptor import SeriesDescriptor
from pypecast.metrics.metrics import *

# %%
df = pd.read_csv('../data/processed/merged_90_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
#test_df = pd.read_csv('../data/processed/test/merged_4_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
df = df[df.Simb == 'PETR4'].Med
dummy = pd.read_csv('../data/example/dummy.csv')
dummy = dummy.Sales.loc[:35].apply(lambda x: float(x))

# %%
series = dummy

# %% [markdown]
# ### Descriptor

# %%
sd = SeriesDescriptor()

# %%
sd.full_report(data=series)
# Out:
# -> Description of the series data:
#             Sales
# count   36.000000
# mean   312.600000
# std    148.937164
# min    119.300000
# 25%    192.450000
# 50%    280.150000
# 75%    411.100000
# max    682.000000
# -------------------- Histogram --------------------
# -> Autocorrelation and partial autocorrelation:
# -> Checking for trends:
# -> Checking for outliers:
# -> Checking for long-run cycles:
# -> Checking if series variance is constant:
# -> Checking for abrupt changes:

# %%
n_lag = 5
n_seq = 3

bf = BuildFeaturesSupervised(n_lag, n_seq,difference=True,scaler_type='norm')

# %%
scaler, train, test = bf.transform_data(series)

# %%
model = Simple_LSTM(n_lag, n_seq, 5)

# %%
model.fit(train, n_batch = 1, n_epoch=100, early_stopping=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6cef2d6d6576> in <module>()
# ----> 1 model.fit(train, n_batch = 1, n_epoch=100, early_stopping=True, loss=rmse)
#
# ~/PypeCast/pypecast/models/simple_lstm.py in fit(self, train, n_batch, n_epoch, loss, opt, early_stopping)
#      79             es = early_stopping
#      80         # fit network
# ---> 81         self._model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2, shuffle=False, validation_split=0.2, callbacks=[es])
#      82
#      83         print('-'*60)
#
# ~/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     948             sample_weight=sample_weight,
#     949             class_weight=class_weight,
# --> 950             batch_size=batch_size)
#     951         # Prepare validation data.
#     952         do_validation = False
#
# ~/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     718                              metrics=self.metrics,
#     719                              loss_weights=self.loss_weights,
# --> 720                              target_tensors=target_tensors)
#     721
#     722         # If `x` and `y` were all symbolic,
#
# ~/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#     331                 with K.name_scope(self.output_names[i] + '_loss'):
#     332                     output_loss = weighted_loss(y_true, y_pred,
# --> 333                                                 sample_weight, mask)
#     334                 if len(self.outputs) > 1:
#     335                     self.metrics_tensors.append(output_loss)
#
# ~/anaconda3/lib/python3.5/site-packages/keras/engine/training_utils.py in weighted(y_true, y_pred, weights, mask)
#     401         """
#     402         # score_array has ndim >= 2
# --> 403         score_array = fn(y_true, y_pred)
#     404         if mask is not None:
#     405             # Cast the mask to floatX to avoid float64 upcasting in Theano
#
# ~/PypeCast/pypecast/metrics/metrics.py in rmse(y_true, y_pred)
#      15     :return: RMSE
#      16     """
# ---> 17     return np.sqrt(mean_squared_error(y_true, y_pred))
#      18
#      19 def mse(y_true, y_pred):
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     237     """
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#     241     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      74     """
#      75     check_consistent_length(y_true, y_pred)
# ---> 76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     560         # make sure we actually converted to numeric:
#     561         if dtype_numeric and array.dtype.kind == "O":
# --> 562             array = array.astype(np.float64)
#     563         if not allow_nd and array.ndim >= 3:
#     564             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: setting an array element with a sequence.

# %%
forecasts = model.forecast_series(test=test, scaler=scaler, orig_series=series)

# %%
model.evaluate_forecast()
# Out:
# --------------------Forecast evaluation--------------------
#
# Instant t+1
# t+1 RMSE: 113.993107
# t+1 MAE: 98.280927
# t+1 MAPE: 0.192368
# t+1 sMAPE: 0.197695
#
# Instant t+2
# t+2 RMSE: 82.451925
# t+2 MAE: 70.430115
# t+2 MAPE: 0.133244
# t+2 sMAPE: 0.141218
#
# Instant t+3
# t+3 RMSE: 134.655670
# t+3 MAE: 119.689323
# t+3 MAPE: 0.213414
# t+3 sMAPE: 0.234183

# %%
model.plot_forecasts(forecasts=forecasts,series=series, test=test)
