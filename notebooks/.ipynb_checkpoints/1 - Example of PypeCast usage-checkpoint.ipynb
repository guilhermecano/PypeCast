# %% [markdown]
# # PypeCast - Simple example

# %% [markdown]
# ### Import the essential classes

# %%
import pandas as pd
from pypecast.models import MLP, Simple_LSTM
from pypecast.features import BuildFeaturesSupervised
from pypecast.descriptor import SeriesDescriptor
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('../data/processed/merged_90_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
#test_df = pd.read_csv('../data/processed/test/merged_4_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
df = df[df.Simb == 'PETR4'].Med
dummy = pd.read_csv('../data/example/dummy.csv')
dummy = dummy.Sales.loc[:35].apply(lambda x: float(x))
series = dummy

# %% [markdown]
# ### Descriptor

# %%
sd = SeriesDescriptor()

# %%
sd.full_report(data=series)
# Out:
# -> Visualization of the series data:
# -> Description of the series data:
#             Sales
# count   36.000000
# mean   312.600000
# std    148.937164
# min    119.300000
# 25%    192.450000
# 50%    280.150000
# 75%    411.100000
# max    682.000000
# -------------------- Histogram --------------------
# -> Autocorrelation and partial autocorrelation:
# -> Checking for outliers:

# %% [markdown]
# ### Build features for supervised learning

# %%
n_lag = 5 #Must define the lag window (ANN input size)
n_seq = 3 #Must also define the number of future timesteps to forecast

bf = BuildFeaturesSupervised(n_lag, n_seq,difference=True,scaler_type='norm')

# %%
scaler, train, test = bf.transform_data(series)

# %% [markdown]
# ### Define a PypeCast Model

# %%
model = Simple_LSTM(n_lag, n_seq, 5)

# %% [markdown]
# #### Fit the model on training set

# %%
model.fit(train, n_batch = 1, n_epoch=100, early_stopping=True)
# Out:
# Train on 16 samples, validate on 5 samples
# Epoch 1/100
#  - 1s - loss: 0.1733 - val_loss: 0.1693
# Epoch 2/100
#  - 0s - loss: 0.1710 - val_loss: 0.1674
# Epoch 3/100
#  - 0s - loss: 0.1691 - val_loss: 0.1656
# Epoch 4/100
#  - 0s - loss: 0.1674 - val_loss: 0.1639
# Epoch 5/100
#  - 0s - loss: 0.1658 - val_loss: 0.1622
# Epoch 6/100
#  - 0s - loss: 0.1642 - val_loss: 0.1606
# Epoch 7/100
#  - 0s - loss: 0.1628 - val_loss: 0.1591
# Epoch 8/100
#  - 0s - loss: 0.1614 - val_loss: 0.1576
# Epoch 9/100
#  - 0s - loss: 0.1601 - val_loss: 0.1562
# Epoch 10/100
#  - 0s - loss: 0.1589 - val_loss: 0.1547
# Epoch 11/100
#  - 0s - loss: 0.1577 - val_loss: 0.1534
# Epoch 12/100
#  - 0s - loss: 0.1566 - val_loss: 0.1520
# Epoch 13/100
#  - 0s - loss: 0.1556 - val_loss: 0.1507
# Epoch 14/100
#  - 0s - loss: 0.1546 - val_loss: 0.1494
# Epoch 15/100
#  - 0s - loss: 0.1536 - val_loss: 0.1481
# Epoch 16/100
#  - 0s - loss: 0.1527 - val_loss: 0.1468
# Epoch 17/100
#  - 0s - loss: 0.1518 - val_loss: 0.1456
# Epoch 18/100
#  - 0s - loss: 0.1510 - val_loss: 0.1444
# Epoch 19/100
#  - 0s - loss: 0.1501 - val_loss: 0.1432
# Epoch 20/100
#  - 0s - loss: 0.1493 - val_loss: 0.1420
# Epoch 21/100
#  - 0s - loss: 0.1486 - val_loss: 0.1408
# Epoch 22/100
#  - 0s - loss: 0.1478 - val_loss: 0.1396
# Epoch 23/100
#  - 0s - loss: 0.1471 - val_loss: 0.1385
# Epoch 24/100
#  - 0s - loss: 0.1464 - val_loss: 0.1373
# Epoch 25/100
#  - 0s - loss: 0.1458 - val_loss: 0.1362
# Epoch 26/100
#  - 0s - loss: 0.1451 - val_loss: 0.1350
# Epoch 27/100
#  - 0s - loss: 0.1445 - val_loss: 0.1339
# Epoch 28/100
#  - 0s - loss: 0.1439 - val_loss: 0.1328
# Epoch 29/100
#  - 0s - loss: 0.1433 - val_loss: 0.1317
# Epoch 30/100
#  - 0s - loss: 0.1427 - val_loss: 0.1306
# Epoch 31/100
#  - 0s - loss: 0.1421 - val_loss: 0.1296
# Epoch 32/100
#  - 0s - loss: 0.1415 - val_loss: 0.1285
# Epoch 33/100
#  - 0s - loss: 0.1410 - val_loss: 0.1275
# Epoch 34/100
#  - 0s - loss: 0.1405 - val_loss: 0.1264
# Epoch 35/100
#  - 0s - loss: 0.1400 - val_loss: 0.1254
# Epoch 36/100
#  - 0s - loss: 0.1394 - val_loss: 0.1244
# Epoch 37/100
#  - 0s - loss: 0.1390 - val_loss: 0.1234
# Epoch 38/100
#  - 0s - loss: 0.1385 - val_loss: 0.1224
# Epoch 39/100
#  - 0s - loss: 0.1380 - val_loss: 0.1215
# Epoch 40/100
#  - 0s - loss: 0.1375 - val_loss: 0.1205
# Epoch 41/100
#  - 0s - loss: 0.1371 - val_loss: 0.1196
# Epoch 42/100
#  - 0s - loss: 0.1366 - val_loss: 0.1187
# Epoch 43/100
#  - 0s - loss: 0.1362 - val_loss: 0.1178
# Epoch 44/100
#  - 0s - loss: 0.1358 - val_loss: 0.1169
# Epoch 45/100
#  - 0s - loss: 0.1354 - val_loss: 0.1160
# Epoch 46/100
#  - 0s - loss: 0.1350 - val_loss: 0.1152
# Epoch 47/100
#  - 0s - loss: 0.1346 - val_loss: 0.1143
# Epoch 48/100
#  - 0s - loss: 0.1342 - val_loss: 0.1135
# Epoch 49/100
#  - 0s - loss: 0.1338 - val_loss: 0.1127
# Epoch 50/100
#  - 0s - loss: 0.1334 - val_loss: 0.1119
# Epoch 51/100
#  - 0s - loss: 0.1330 - val_loss: 0.1111
# Epoch 52/100
#  - 0s - loss: 0.1327 - val_loss: 0.1104
# Epoch 53/100
#  - 0s - loss: 0.1323 - val_loss: 0.1096
# Epoch 54/100
#  - 0s - loss: 0.1320 - val_loss: 0.1089
# Epoch 55/100
#  - 0s - loss: 0.1316 - val_loss: 0.1082
# Epoch 56/100
#  - 0s - loss: 0.1313 - val_loss: 0.1075
# Epoch 57/100
#  - 0s - loss: 0.1309 - val_loss: 0.1068
# Epoch 58/100
#  - 0s - loss: 0.1306 - val_loss: 0.1062
# Epoch 59/100
#  - 0s - loss: 0.1303 - val_loss: 0.1055
# Epoch 60/100
#  - 0s - loss: 0.1300 - val_loss: 0.1049
# Epoch 61/100
#  - 0s - loss: 0.1297 - val_loss: 0.1042
# Epoch 62/100
#  - 0s - loss: 0.1294 - val_loss: 0.1036
# Epoch 63/100
#  - 0s - loss: 0.1291 - val_loss: 0.1030
# Epoch 64/100
#  - 0s - loss: 0.1288 - val_loss: 0.1025
# Epoch 65/100
#  - 0s - loss: 0.1285 - val_loss: 0.1019
# Epoch 66/100
#  - 0s - loss: 0.1282 - val_loss: 0.1013
# Epoch 67/100
#  - 0s - loss: 0.1279 - val_loss: 0.1008
# Epoch 68/100
#  - 0s - loss: 0.1276 - val_loss: 0.1003
# Epoch 69/100
#  - 0s - loss: 0.1273 - val_loss: 0.0997
# Epoch 70/100
#  - 0s - loss: 0.1271 - val_loss: 0.0992
# Epoch 71/100
#  - 0s - loss: 0.1268 - val_loss: 0.0987
# Epoch 72/100
#  - 0s - loss: 0.1265 - val_loss: 0.0983
# Epoch 73/100
#  - 0s - loss: 0.1263 - val_loss: 0.0978
# Epoch 74/100
#  - 0s - loss: 0.1260 - val_loss: 0.0973
# Epoch 75/100
#  - 0s - loss: 0.1257 - val_loss: 0.0969
# Epoch 76/100
#  - 0s - loss: 0.1255 - val_loss: 0.0964
# Epoch 77/100
#  - 0s - loss: 0.1252 - val_loss: 0.0960
# Epoch 78/100
#  - 0s - loss: 0.1250 - val_loss: 0.0956
# Epoch 79/100
#  - 0s - loss: 0.1248 - val_loss: 0.0952
# Epoch 80/100
#  - 0s - loss: 0.1245 - val_loss: 0.0948
# Epoch 81/100
#  - 0s - loss: 0.1243 - val_loss: 0.0944
# Epoch 82/100
#  - 0s - loss: 0.1240 - val_loss: 0.0940
# Epoch 83/100
#  - 0s - loss: 0.1238 - val_loss: 0.0936
# Epoch 84/100
#  - 0s - loss: 0.1236 - val_loss: 0.0932
# Epoch 85/100
#  - 0s - loss: 0.1234 - val_loss: 0.0929
# Epoch 86/100
#  - 0s - loss: 0.1231 - val_loss: 0.0925
# Epoch 87/100
#  - 0s - loss: 0.1229 - val_loss: 0.0922
# Epoch 88/100
#  - 0s - loss: 0.1227 - val_loss: 0.0918
# Epoch 89/100
#  - 0s - loss: 0.1225 - val_loss: 0.0915
# Epoch 90/100
#  - 0s - loss: 0.1223 - val_loss: 0.0912
# Epoch 91/100
#  - 0s - loss: 0.1221 - val_loss: 0.0909
# Epoch 92/100
#  - 0s - loss: 0.1218 - val_loss: 0.0905
# Epoch 93/100
#  - 0s - loss: 0.1216 - val_loss: 0.0902
# Epoch 94/100
#  - 0s - loss: 0.1214 - val_loss: 0.0899
# Epoch 95/100
#  - 0s - loss: 0.1212 - val_loss: 0.0896
# Epoch 96/100
#  - 0s - loss: 0.1210 - val_loss: 0.0893
# Epoch 97/100
#  - 0s - loss: 0.1208 - val_loss: 0.0891
# Epoch 98/100
#  - 0s - loss: 0.1206 - val_loss: 0.0888
# Epoch 99/100
#  - 0s - loss: 0.1204 - val_loss: 0.0885
# Epoch 100/100
#  - 0s - loss: 0.1202 - val_loss: 0.0882
# ------------------------------------------------------------
# Model trained

# %% [markdown]
# #### Make forecasts in the test set and evaluate them

# %%
forecasts = model.forecast_series(test=test, scaler=scaler, orig_series=series)

# %%
model.evaluate_forecast(save_report=True)
# Out:
# --------------------Forecast evaluation--------------------
#
# Instant t+1
# t+1 RMSE: 128.290380
# t+1 MAE: 112.430481
# t+1 MAPE: 0.223186
# t+1 sMAPE: 0.224729
# ------------------------------------------------------------
# Instant t+2
# t+2 RMSE: 91.890088
# t+2 MAE: 82.828965
# t+2 MAPE: 0.159173
# t+2 sMAPE: 0.165549
# ------------------------------------------------------------
# Instant t+3
# t+3 RMSE: 126.029202
# t+3 MAE: 107.833780
# t+3 MAPE: 0.194675
# t+3 sMAPE: 0.212796
# ------------------------------------------------------------

# %%
model.plot_forecasts(forecasts=forecasts,series=series, test=test)
