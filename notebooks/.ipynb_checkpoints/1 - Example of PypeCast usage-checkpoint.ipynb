# %% [markdown]
# # PypeCast - Simple example

# %% [markdown]
# ### Import the essential classes

# %%
import pandas as pd
import numpy as np
from pypecast.models import MLP, Simple_LSTM
from pypecast.features import BuildFeaturesSupervised
from pypecast.descriptor import SeriesDescriptor

# %%
df = pd.read_csv('../data/processed/merged_90_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
#test_df = pd.read_csv('../data/processed/test/merged_4_days.csv').drop(['Unnamed: 0', 'Var'], axis=1)
df = df[df.Simb == 'PETR4'].Med
dummy = pd.read_csv('../data/example/dummy.csv')
dummy = dummy.Sales.loc[:35].apply(lambda x: float(x))
series = dummy

# %% [markdown]
# ### Descriptor

# %%
sd = SeriesDescriptor()

# %%
sd.full_report(data=series)
# Out:
# -> Visualization of the series data:
# -> Description of the series data:
#             Sales
# count   36.000000
# mean   312.600000
# std    148.937164
# min    119.300000
# 25%    192.450000
# 50%    280.150000
# 75%    411.100000
# max    682.000000
# -------------------- Histogram --------------------
# -> Autocorrelation and partial autocorrelation:
# -> Checking for outliers:

# %% [markdown]
# ### Build features for supervised learning

# %%
n_lag = 5 #Must define the lag window (ANN input size)
n_seq = 3 #Must also define the number of future timesteps to forecast

bf = BuildFeaturesSupervised(n_lag,n_seq, difference=True,scaler_type='norm')

# %%
scaler, train, test = bf.transform_data(series)

# %% [markdown]
# ### Define a PypeCast Model

# %%
model = Simple_LSTM(n_lag, n_seq, 5)

# %% [markdown]
# #### Fit the model on training set

# %%
model.fit(train, n_batch = 1, n_epoch=100, early_stopping=True)
# Out:
# Train on 16 samples, validate on 5 samples
# Epoch 1/100
#  - 1s - loss: 0.1786 - val_loss: 0.2032
# Epoch 2/100
#  - 0s - loss: 0.1757 - val_loss: 0.1991
# Epoch 3/100
#  - 0s - loss: 0.1733 - val_loss: 0.1952
# Epoch 4/100
#  - 0s - loss: 0.1711 - val_loss: 0.1917
# Epoch 5/100
#  - 0s - loss: 0.1691 - val_loss: 0.1883
# Epoch 6/100
#  - 0s - loss: 0.1672 - val_loss: 0.1852
# Epoch 7/100
#  - 0s - loss: 0.1655 - val_loss: 0.1823
# Epoch 8/100
#  - 0s - loss: 0.1639 - val_loss: 0.1795
# Epoch 9/100
#  - 0s - loss: 0.1624 - val_loss: 0.1769
# Epoch 10/100
#  - 0s - loss: 0.1610 - val_loss: 0.1743
# Epoch 11/100
#  - 0s - loss: 0.1597 - val_loss: 0.1719
# Epoch 12/100
#  - 0s - loss: 0.1584 - val_loss: 0.1695
# Epoch 13/100
#  - 0s - loss: 0.1572 - val_loss: 0.1672
# Epoch 14/100
#  - 0s - loss: 0.1561 - val_loss: 0.1649
# Epoch 15/100
#  - 0s - loss: 0.1550 - val_loss: 0.1627
# Epoch 16/100
#  - 0s - loss: 0.1539 - val_loss: 0.1605
# Epoch 17/100
#  - 0s - loss: 0.1529 - val_loss: 0.1583
# Epoch 18/100
#  - 0s - loss: 0.1519 - val_loss: 0.1561
# Epoch 19/100
#  - 0s - loss: 0.1509 - val_loss: 0.1540
# Epoch 20/100
#  - 0s - loss: 0.1499 - val_loss: 0.1518
# Epoch 21/100
#  - 0s - loss: 0.1490 - val_loss: 0.1496
# Epoch 22/100
#  - 0s - loss: 0.1481 - val_loss: 0.1475
# Epoch 23/100
#  - 0s - loss: 0.1471 - val_loss: 0.1453
# Epoch 24/100
#  - 0s - loss: 0.1462 - val_loss: 0.1431
# Epoch 25/100
#  - 0s - loss: 0.1454 - val_loss: 0.1409
# Epoch 26/100
#  - 0s - loss: 0.1445 - val_loss: 0.1388
# Epoch 27/100
#  - 0s - loss: 0.1436 - val_loss: 0.1366
# Epoch 28/100
#  - 0s - loss: 0.1428 - val_loss: 0.1344
# Epoch 29/100
#  - 0s - loss: 0.1419 - val_loss: 0.1322
# Epoch 30/100
#  - 0s - loss: 0.1411 - val_loss: 0.1300
# Epoch 31/100
#  - 0s - loss: 0.1402 - val_loss: 0.1279
# Epoch 32/100
#  - 0s - loss: 0.1394 - val_loss: 0.1257
# Epoch 33/100
#  - 0s - loss: 0.1386 - val_loss: 0.1236
# Epoch 34/100
#  - 0s - loss: 0.1378 - val_loss: 0.1215
# Epoch 35/100
#  - 0s - loss: 0.1371 - val_loss: 0.1194
# Epoch 36/100
#  - 0s - loss: 0.1363 - val_loss: 0.1173
# Epoch 37/100
#  - 0s - loss: 0.1356 - val_loss: 0.1153
# Epoch 38/100
#  - 0s - loss: 0.1348 - val_loss: 0.1133
# Epoch 39/100
#  - 0s - loss: 0.1341 - val_loss: 0.1113
# Epoch 40/100
#  - 0s - loss: 0.1334 - val_loss: 0.1094
# Epoch 41/100
#  - 0s - loss: 0.1328 - val_loss: 0.1075
# Epoch 42/100
#  - 0s - loss: 0.1321 - val_loss: 0.1057
# Epoch 43/100
#  - 0s - loss: 0.1315 - val_loss: 0.1039
# Epoch 44/100
#  - 0s - loss: 0.1309 - val_loss: 0.1022
# Epoch 45/100
#  - 0s - loss: 0.1303 - val_loss: 0.1005
# Epoch 46/100
#  - 0s - loss: 0.1297 - val_loss: 0.0989
# Epoch 47/100
#  - 0s - loss: 0.1291 - val_loss: 0.0974
# Epoch 48/100
#  - 0s - loss: 0.1286 - val_loss: 0.0959
# Epoch 49/100
#  - 0s - loss: 0.1280 - val_loss: 0.0944
# Epoch 50/100
#  - 0s - loss: 0.1275 - val_loss: 0.0931
# Epoch 51/100
#  - 0s - loss: 0.1270 - val_loss: 0.0918
# Epoch 52/100
#  - 0s - loss: 0.1265 - val_loss: 0.0905
# Epoch 53/100
#  - 0s - loss: 0.1261 - val_loss: 0.0893
# Epoch 54/100
#  - 0s - loss: 0.1256 - val_loss: 0.0882
# Epoch 55/100
#  - 0s - loss: 0.1252 - val_loss: 0.0871
# Epoch 56/100
#  - 0s - loss: 0.1248 - val_loss: 0.0861
# Epoch 57/100
#  - 0s - loss: 0.1244 - val_loss: 0.0851
# Epoch 58/100
#  - 0s - loss: 0.1240 - val_loss: 0.0842
# Epoch 59/100
#  - 0s - loss: 0.1236 - val_loss: 0.0833
# Epoch 60/100
#  - 0s - loss: 0.1232 - val_loss: 0.0824
# Epoch 61/100
#  - 0s - loss: 0.1229 - val_loss: 0.0817
# Epoch 62/100
#  - 0s - loss: 0.1225 - val_loss: 0.0809
# Epoch 63/100
#  - 0s - loss: 0.1222 - val_loss: 0.0802
# Epoch 64/100
#  - 0s - loss: 0.1219 - val_loss: 0.0796
# Epoch 65/100
#  - 0s - loss: 0.1215 - val_loss: 0.0790
# Epoch 66/100
#  - 0s - loss: 0.1212 - val_loss: 0.0784
# Epoch 67/100
#  - 0s - loss: 0.1209 - val_loss: 0.0778
# Epoch 68/100
#  - 0s - loss: 0.1206 - val_loss: 0.0773
# Epoch 69/100
#  - 0s - loss: 0.1204 - val_loss: 0.0768
# Epoch 70/100
#  - 0s - loss: 0.1201 - val_loss: 0.0764
# Epoch 71/100
#  - 0s - loss: 0.1198 - val_loss: 0.0760
# Epoch 72/100
#  - 0s - loss: 0.1196 - val_loss: 0.0756
# Epoch 73/100
#  - 0s - loss: 0.1193 - val_loss: 0.0752
# Epoch 74/100
#  - 0s - loss: 0.1190 - val_loss: 0.0748
# Epoch 75/100
#  - 0s - loss: 0.1188 - val_loss: 0.0745
# Epoch 76/100
#  - 0s - loss: 0.1186 - val_loss: 0.0742
# Epoch 77/100
#  - 0s - loss: 0.1183 - val_loss: 0.0739
# Epoch 78/100
#  - 0s - loss: 0.1181 - val_loss: 0.0736
# Epoch 79/100
#  - 0s - loss: 0.1179 - val_loss: 0.0734
# Epoch 80/100
#  - 0s - loss: 0.1176 - val_loss: 0.0731
# Epoch 81/100
#  - 0s - loss: 0.1174 - val_loss: 0.0729
# Epoch 82/100
#  - 0s - loss: 0.1172 - val_loss: 0.0727
# Epoch 83/100
#  - 0s - loss: 0.1170 - val_loss: 0.0725
# Epoch 84/100
#  - 0s - loss: 0.1168 - val_loss: 0.0723
# Epoch 85/100
#  - 0s - loss: 0.1166 - val_loss: 0.0721
# Epoch 86/100
#  - 0s - loss: 0.1164 - val_loss: 0.0720
# Epoch 87/100
#  - 0s - loss: 0.1162 - val_loss: 0.0718
# Epoch 88/100
#  - 0s - loss: 0.1160 - val_loss: 0.0716
# Epoch 89/100
#  - 0s - loss: 0.1158 - val_loss: 0.0715
# Epoch 90/100
#  - 0s - loss: 0.1156 - val_loss: 0.0714
# Epoch 91/100
#  - 0s - loss: 0.1155 - val_loss: 0.0712
# Epoch 92/100
#  - 0s - loss: 0.1153 - val_loss: 0.0711
# Epoch 93/100
#  - 0s - loss: 0.1151 - val_loss: 0.0710
# Epoch 94/100
#  - 0s - loss: 0.1149 - val_loss: 0.0708
# Epoch 95/100
#  - 0s - loss: 0.1148 - val_loss: 0.0707
# Epoch 96/100
#  - 0s - loss: 0.1146 - val_loss: 0.0706
# Epoch 97/100
#  - 0s - loss: 0.1144 - val_loss: 0.0705
# Epoch 98/100
#  - 0s - loss: 0.1143 - val_loss: 0.0704
# Epoch 99/100
#  - 0s - loss: 0.1141 - val_loss: 0.0703
# Epoch 100/100
#  - 0s - loss: 0.1139 - val_loss: 0.0702
# ------------------------------------------------------------
# Model trained

# %% [markdown]
# #### Make forecasts in the test set and evaluate them

# %%
forecasts = model.forecast_series(test=test, scaler=scaler, orig_series=series)

# %%
model.evaluate_forecast(save_report=True)
# Out:
# --------------------Forecast evaluation--------------------
#
# Step t+1
# t+1 RMSE: 131.703636
# t+1 MAE: 117.747719
# t+1 MAPE: 0.212415
# t+1 sMAPE: 0.225706
# ------------------------------------------------------------
# Step t+2
# t+2 RMSE: 83.618865
# t+2 MAE: 72.827562
# t+2 MAPE: 0.128345
# t+2 sMAPE: 0.130881
# ------------------------------------------------------------
# Step t+3
# t+3 RMSE: 129.258413
# t+3 MAE: 104.621738
# t+3 MAPE: 0.163366
# t+3 sMAPE: 0.184545
# ------------------------------------------------------------
#
# --------------------Naive forecast evaluation--------------------
# Step t+1
# t+1 RMSE: 203.274611
# t+1 MAE: 196.775000
# t+1 MAPE: 0.372279
# t+1 sMAPE: 0.368784
# ------------------------------------------------------------
# Step t+2
# t+2 RMSE: 82.088474
# t+2 MAE: 76.175000
# t+2 MAPE: 0.136235
# t+2 sMAPE: 0.138175
# ------------------------------------------------------------
# Step t+3
# t+3 RMSE: 159.117017
# t+3 MAE: 138.400000
# t+3 MAPE: 0.230634
# t+3 sMAPE: 0.257964
# ------------------------------------------------------------
#
# --------------------Evaluation for each forecast--------------------
# Index 1 RMSE: 156.424192
# Index 1 MAE: 139.007419
# Index 1 MAPE: 0.232980
# Index 1 sMAPE: 0.264076
# ------------------------------------------------------------
# Index 2 RMSE: 99.800659
# Index 2 MAE: 88.328838
# Index 2 MAPE: 0.168127
# Index 2 sMAPE: 0.166267
# ------------------------------------------------------------
# Index 3 RMSE: 118.065542
# Index 3 MAE: 93.126026
# Index 3 MAPE: 0.147441
# Index 3 sMAPE: 0.165520
# ------------------------------------------------------------
# Index 4 RMSE: 79.746023
# Index 4 MAE: 73.133742
# Index 4 MAPE: 0.123620
# Index 4 sMAPE: 0.125646
# ------------------------------------------------------------

# %%
model.plot_forecasts(forecasts=forecasts,series=series, test=test)

# %%
series
